# %%
import pandas as pd

# %% [markdown]
# # Determine
# **There are many ways to decide the quality of a community, some people like to decide by the restaurant, or some people like to decide by their favorite gym. But I think health is the most important thing, so I think a good community must have enough kinds of hospitals to provide corresponding services to the people in the community.**

# %%
Hospital = pd.read_csv("AlleghenyCountyHospitals.csv")
Hospital
# Out:
#                                     Facility  \
# 0                           UPMC Children's
# 1                                 UPMC Magee
# 2                            UPMC McKeesport
# 3                                 UPMC Mercy
# 4                             UPMC Passavant
# 5                          UPMC Presbyterian
# 6                             UPMC Shadyside
# 7                        UPMC St. Margaret's
# 8                                  UPMC East
# 9                 Allegheny General Hospital
# 10                 Allegheny Valley Hospital
# 11                  Forbes Regional Hospital
# 12                        West Penn Hospital
# 13                    VA Pittsburgh Hospital
# 14                  Heritage Valley Hospital
# 15               Jefferson Regional Hospital
# 16                      Ohio Valley Hospital
# 17                         St Clair Hospital
# 18               Health South Rehab Sewickly
# 19             Southwood Psychatric Hospital
# 20           Lifecare Hospital of Monroville
# 21  Health South  Harmaville Rehabilitaiton
# 22         Lifecare Hospital of PGH Suburban
#
#                                               Address          Y          X
# 0               4401 Penn Avenue Pittsburgh, PA 15224  40.467315 -79.953590
# 1             300 Halkett Street Pittsburgh, PA 15213  40.436889 -79.960700
# 2                1500 5th Avenue McKeesport, PA 15132  40.351343 -79.849457
# 3             1400 Locust Street Pittsburgh, PA 15219  40.436137 -79.985285
# 4         9100 Babcock Boulevard Pittsburgh, PA 15237  40.573319 -80.014525
# 5             3601 Fifth Avenue Pittsburgh, PA  15213  40.441544 -79.959356
# 6               5230 Center Ave Pittsburgh, PA  15232  40.454845 -79.939793
# 7              815 Freeport Road Pittsburgh, PA 15215  40.489286 -79.895994
# 8        2775 Mosside Boulevard Monroeville, PA 15146  40.436561 -79.760197
# 9                     AGH 320 E. North Ave, PGH 15212  40.457010 -80.003724
# 10  Allegheny Valley 1301 Carlisle Street, Natrona...  40.619129 -79.737849
# 11  Forbes Regional 2570 Haymaker Rd, Monroeville,...  40.427585 -79.747217
# 12           West Penn 4800 Friendship Ave, PGH 15224  40.461453 -79.946364
# 13        VA Pittsburgh 4100 Allequippa St, PGH 15261  40.447391 -79.959788
# 14  Heritage Valley Sewickley 720 Blackburn Rd, Se...  40.543454 -80.177601
# 15  Jefferson Regional 565 Coal Valley Rd, Clairto...  40.318440 -79.933488
# 16   Ohio Valley 25 Heckel Rd, McKees Rocks, PA 15136  40.472755 -80.090742
# 17            St. Clair 1000 Bower Hill Rd, PGH 15243  40.378099 -80.066610
# 18           303 Camp Meeting Rd, Sewickley, PA 15143  40.576315 -80.203135
# 19          2575 Boyce Plaza Rd, Pittsburgh, PA 15241  40.321195 -80.112625
# 20          2380 McGinley Road, Monroeville, PA 15146  40.424369 -79.745967
# 21              320 Guys Run Rd, Pittsburgh, PA 15238  40.536213 -79.849228
# 22            100 S Jackson Ave, Pittsburgh, PA 15202  40.494569 -80.060335

# %% [markdown]
# **We can see a variety of different hospitals from the data, which means that different hospitals serve different types of citizens, such as hospitals built for children.**

# %% [markdown]
# # **Tpyes**
#
# A good community hospital should provide services for people of different ages or provide different services for different genders.
#
# These are some Name of the hosputals and their tpyes:
#
# Name  | Tpyes
# -------|-------
# UPMC Children's | For children
# UPMC Magee | For Women
# ...|...
# ...|...
# Allegheny General Hospital    | For everyone
#
# **Setting up hospitals for everyone is the best option.**

# %% [markdown]
# ![](https://media2.giphy.com/media/K61ByIKDUSs9P2KdGY/giphy.gif?cid=ecf05e47r3ygygn6vuu7qomxcrqgqcn2lpiifffq9u0qe9pf&rid=giphy.gif&ct=g)

# %% [markdown]
# # Region
# **We can see that there are many hospitals in the main urban area, which also shows that there is a great demand in the main urban area.**
#
# ![title](Hospital.png)
#
# **Allegheny county has more and higher quality hospitals around the community than any other neighborhood too.**

# %% [markdown]
# # In the end
#
# **This is just my personal opinion as I think health always comes first. At last, I wish everyone a healthy life.**
#
# ![](https://media0.giphy.com/media/JpdvqUB2xeydKPZA0I/giphy.gif?cid=ecf05e47r3ygygn6vuu7qomxcrqgqcn2lpiifffq9u0qe9pf&rid=giphy.gif&ct=g)
